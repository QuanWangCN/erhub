# %%
library(GGally)
library(network)
library(sna)
library(scales)
NetC2=read.csv(file="~/Desktop/Rtest/miRTarBaseHomo.csv")
Net = network(x = NetC2, directed = TRUE)
ggnet2(net = Net,alpha = 0.9,size = 4)

##先把所有差异mrna和mirna导入
mir.High=data.frame(c("hsa-miR-4521","hsa-miR-205-5p","hsa-miR-873-3p","hsa-miR-663b","hsa-miR-1973","hsa-miR-873-5p","hsa-miR-4485-3p","hsa-miR-139-5p","hsa-miR-1297","hsa-miR-210-3p",
                     "hsa-miR-27a-5p","hsa-miR-33a-5p","hsa-miR-184","hsa-miR-19a-3p","hsa-miR-338-5p","hsa-miR-320d","hsa-miR-19b-3p","hsa-miR-6868-3p","hsa-miR-5683","hsa-miR-629-3p",
                     "hsa-miR-23b-3p","hsa-miR-34c-5p"))
colnames(mir.High)="Name"
mir.Low=data.frame(c("hsa-miR-4662a-5p","hsa-miR-141-3p","hsa-miR-1299","hsa-miR-7975","hsa-miR-92b-3p",
                    "hsa-miR-199b-5p","hsa-miR-148a-3p","hsa-miR-2682-5p","hsa-miR-7705","hsa-miR-214-5p",
                    "hsa-miR-223-3p","hsa-miR-142-5p","hsa-miR-3909","hsa-miR-3690","hsa-miR-4732-3p",
                    "hsa-miR-1260b","hsa-miR-182-5p","hsa-miR-766-3p","hsa-miR-146b-5p","hsa-miR-122-5p",
                    "hsa-miR-96-5p","hsa-miR-4687-5p","hsa-miR-504-5p","hsa-miR-146b-3p","hsa-miR-3152-5p",
                    "hsa-miR-4709-5p","hsa-miR-183-5p","hsa-miR-6501-5p","hsa-miR-548ar-3p","hsa-miR-1260a",
                    "hsa-miR-516a-5p","hsa-miR-1304-3p","hsa-miR-891a-5p"))
colnames(mir.Low)="Name"
mir.All=rbind(mir.High,mir.Low)
m.Up=data.frame(c("ENO4","GUSBP8","LNX2","HSD3B7","ZER1","MIER2","ATXN7L3B","TOX2","GOPC","SNORD4B","ZNF137P","GIT1","YBX3P1","GPER1","RNU1-1","TLR9","RDH13","UBA1","CAD","MAGEB6","WASH3P","FAM138A","STC2","TLE2","RDH16","LCN1P2","SIRT1","PRY2","DAZ3","FAM179B","LOC100129053","RFNG","SMG9","HCG27","EPHX4","LOC100132356","CCDC124","ZNF786","IRF2BP1","GTF2IRD2","FBXL3","USP14","EPHB4","CDCA4","POLA1","SEMA4B","dnmbp","FXR2","RIC8B","PKD1","TMEM39A","BRPF1","CNOT3","C12orf60","Tmem91","stx1a","ZNF493","GSTTP2","LOC284241","CLCN3","EEF1A1P32","RNU4-1","PLEKHG1","FLJ45508","KAT7","ARHGEF26","TUBB4B","PM20D2","SYP","EYS","OGFR","NELL2","ZNF764","C16orf72","TCP11L1","IP6K3","LOC100129112","RPL21P44","POU4F2","TRIM7","LRRC32","PTCRA","CACFD1","SNORA71C","SLC24A3","SIX5","LOC646626","ALKBH2","LOC642204","MMRN1","OR7G2","rnf25","RPL12P18","MAB21L1","ANO1","AHCTF1","NAV2","ZNF836","CNPPD1","SERPING1","GRB10","EH
                    "ZMYND11","LRRC2","VWC2","RASAL2","QKI","ROPN1","PLB1","CENPH","NDUFB2","IL6R","OR8H1","PTGS1","CAP1","DHRS4L1","PHTF1","IMMP2L","PSD","CELF2-AS2","GPR83","ENPP3","SLC26A4","UBASH3B","UTP3","TESPA1","ZNF620","KLHDC8B","PPIL1","PGBD5","ELOVL2","BTF3L4","COMMD3","SLFN14","MOSPD2","ETV2","RBKS","ANKS6","FAHD1","LOC642969","EBF3","MDH1","CLCN5","TTTY14","HIST2H3A","PLA2G16","KCNJ15","LAT2","CD83","CENPVL3","mir27a","CLMP","TLR1","C22orf15","COMMD5","TPST1","FBLN5","LOC731157","VMO1","LOC441806","MIRLET7DHG","LOC440082","MCUB","BAIAP2L2","FAM198A","MIR575","PAX6","SIGLEC16","HAUS6P1","P3H2","GPR162","OR2H1","ALG1","SCARB1","TXNRD3NB","LOC729870","DNAJB13","NOV","SUSD3","OR10A4","SUMF1",
                    "PKD2L1","MIR4435-2HG","OR51S1","LOC441239","MYL12A","ETV5","MORN5","FMO2","ACTBL2","PPP1R17","FA2H","COLCA1","RHOC","whsc1","CECR5","HEXA","PRR12","SIRPB1","FCRLB","PI4KA","DIRC2","LOC730076","SLC16A14","TREM2","BCAS1","CCIN","PAPSS2","GDF3","ERMAP","HFM1","IL16","PRELID3B","FLJ46284","ABR","ATP1A1","DOK3","ARRB1","CNGA1","GNGT2","IQCF1","TRPA1","SIGLEC7","TM6SF1","FEZ1","PDE3B","TRIM75P","LOC441241","CRIPT","SLC29A3","mir187","CLEC9A","DLEU7","PSD4","LOC642335","DYNC1I1","LOC644145","SLC18A1","MGAM2","DHRS9","HTR2B","MBD3L4","OLR1","HPSE","KAZALD1","OSCAR","DES","MAPK6","SERPINA4","vash1","RPS12P9","HKDC1","PSMC1P3","LRFN1","ZCCHC9","Snhg4","LINC00324","LOC728114","NIPBL-AS1","SERPINB1","IKBKE","RAPSN","SLC25A5","ZC3H13","LY86","FRK","Mir802","GAGE12J","HNRNPA1P6","PNMA6B","TSPAN18","TRIM49D2","SAMD4A","FHDC1","MIR148A","DCST2","ATP6V1A","SLC6A19","LINC00937","CD276","SNORD114-29","ARHGAP45","ARPC3P5","SLC35G1","TTTY22","LOC283804","HLA-DRB4","KCNK13","DCN","GABRQ","SMAD5","CFAP65","DEFB103B","MED8","EPHA8","KLRG1","PLEKHF1","KIF13B","C11orf40","C10orf113","DCAF12L2","DHCR7","RASSF3","CNTN3","NCF1C","INE2","ARMC3","CTAGE15","mir15b","ITGA3","ARV1","PBX3","P2RX6","dusp28","SUCO","SNORD102","PDE6H","CORIN","RTN4IP1","GALNT14","HIST1H1B","SSX4B","SKOR1","SLC16A6","ASCL2",
                    "ADAL"))
colnames(m.Down)="Name"
m.all=rbind(m.Up,m.Down)
##找子图，可见xx还有617个点976对关系,xxx还有61个点，99个对关系
NetC2.mir=subset(x = NetC2,NetC2$miRNA %in% mir.All$Name)
NetC2.mir.m=subset(x = NetC2.mir,NetC2.mir$Target.Gene %in% m.all$Name)
Net.mir = network(x = NetC2.mir, directed = T)
Net.mir.m=network(x = NetC2.mir.m,directed = T)
xx=data.frame(Name = network.vertex.names(Net.mir))
xxx=data.frame(Name = network.vertex.names(Net.mir.m))
##找这些点的属性,总共有75（？）/617（976关系）个点重点注释
xx.High=merge(x = xx,y = mir.High)
xx.High$Class="mi"
xx.High$Expression="High"
xx.Low=merge(x = xx,y=mir.Low)
xx.Low$Class="mi"
xx.Low$Expression="Low"
xx.Up=merge(x = xx,y = m.Up)
xx.Up$Class="m"
xx.Up$Expression="Up"
xx.Down=merge(x = xx,y = m.Down)
xx.Down$Class="m"
xx.Down$Expression="Down"
xx.Ann=rbind(xx.High,xx.Low,xx.Up,xx.Down)
#需要上色的在xx.All里面，但是其他的虽然不是差异基因，但是也要给个色，不然顺序不对
mm=merge(x = xx,y = xx.Ann,all.x = T)
write.csv(x = mm,file = "~/Desktop/Test2.csv")
xx.Plus=read.csv(file ="~/Desktop/Rtest/20180916001.Attr3.csv")
NodeColor = merge(x = xx,y = xx.Plus,by = "Name",all.x = T,sort = F)$Expression
Net.mir %v% "Expression" = as.character(NodeColor)
y = RColorBrewer::brewer.pal(8,"Set2")[c(1,2,5,3,4)]
names(y) = levels(NodeColor)
NodeShape=merge(x = xx,y = xx.Plus,by = "Name",all.x = T,sort = F)$Class
Net.mir %v% "Category"= as.character(NodeShape)
ggnet2(net = Net.mir,
       color = "Expression",palette = y,label=T,
       shape = "Category",alpha = 0.9,size = 3,label.size = 3)
# Out:
# Loading required package: ggplot2
# network: Classes for Relational Data
# Version 1.13.0.1 created on 2015-08-31.
# copyright (c) 2005, Carter T. Butts, University of California-Irvine
#                     Mark S. Handcock, University of California -- Los Angeles
#                     David R. Hunter, Penn State University
#                     Martina Morris, University of Washington
#                     Skye Bender-deMoll, University of Washington
#  For citation information, type citation("network").
#  Type help("network-package") to get started.
#
# Loading required package: statnet.common
#
# Attaching package: ‘statnet.common’
#
# The following object is masked from ‘package:base’:
#
#     order
#
# sna: Tools for Social Network Analysis
# Version 2.4 created on 2016-07-23.
# copyright (c) 2005, Carter T. Butts, University of California-Irvine
#  For citation information, type citation("sna").
#  Type help(package="sna") to get started.
# plot without title
# ...

# %%
pdf(file = "~/Desktop/Figure1t3.pdf",width = 6.6929,height =6.6929)
ggnet2(net = Net.mir,
       color = "Expression",palette = y,label=T,
       shape = "Category",alpha = 0.9,size = 2,label.size = 1,legend.position="None")
graphics.off()

# %%
xxx.Ann=merge(x = xxx,y = xx.Ann,by = "Name",all.x = T,sort = F)
xxx.Ann$Class=factor(xxx.Ann$Class)
xxx.Ann$Expression=factor(xxx.Ann$Expression)
NodeColor2 = as.factor(xxx.Ann$Expression)
Net.mir.m %v% "Expression" = as.character(NodeColor2)
y = RColorBrewer::brewer.pal(8,"Set2")[c(1,2,5,4,3)]
names(y) = levels(NodeColor2)
NodeShape2=as.factor(merge(x = xxx,y = xx.Ann,by = "Name",all.x = T,sort = F)$Class)
Net.mir.m %v% "Category"= as.character(NodeShape2)
pdf(file = "~/Desktop/figure2t2.pdf",width = 6.6929,height =3.9370)
ggnet2(net = Net.mir.m,color = "Expression",label = T,palette = y,
       shape = "Category",
       alpha = 0.9,size = 5,label.size = 3)
graphics.off()
