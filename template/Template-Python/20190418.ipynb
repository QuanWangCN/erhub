# %%
import pandas
import numpy

# %%
ts=DataFrame(random.randn(1000, 4),
         index=date_range('1/1/2000', periods=1000),
         columns=['A', 'B', 'C', 'D'])
ts.head()
df=ts.cumsum()
df.plot()

# %%
from plotnine import *
s=read_csv('/Users/quanwang/Desktop/GSE35234.csv')
s.head()
# Out:
#              ID  Name  GSM864305  GSM864306  GSM864307  GSM864308  GSM864309  \
# 0  ILMN_2740859  RELA  10.759555  10.700006  10.248876  10.683346  10.167293
# 1  ILMN_2684234  TLR4   7.455327   7.526695   7.866661   7.573647   7.673132
# 2  ILMN_2690004  TLR4   5.557655   5.469235   5.652486   5.635174   5.632268
# 3  ILMN_2752966  TLR4   6.652486   6.762880   6.841722   6.730640   6.846744
#
#    GSM864310  GSM864311  GSM864312  GSM864313  GSM864314  GSM864315  GSM864316
# 0  10.742899  10.742478  10.645208  10.345516  10.475936  10.012345  10.241030
# 1   7.871597   7.738092   7.519636   7.559951   7.576673   7.322829   7.278914
# 2   5.804776   5.507795   5.692092   5.551516   5.643856   5.485427   5.542258
# 3   6.624978   6.811214   6.429616   6.611763   6.605850   6.666757   6.605850

# %%
(ggplot(s,aes('Name','GSM864305'))+
    geom_point(color='red'))
# Out:
# <ggplot: (-9223372036560315588)>
